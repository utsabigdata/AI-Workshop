# %% [markdown]
# ## IBM Watson API Service

# %%
# !pip install --upgrade --user --force watson-developer-cloud

# %%
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, EntitiesOptions, KeywordsOptions, EmotionOptions

# %% [markdown]
# ## Input test files and sentence

# %%
text_to_analyze ='I am learning so much from this AI course. Python is awesome and super easy to learn' 

file1 = open("data/news1.txt","r") 

file2 = open("data/news2.txt", "r")

# %% [markdown]
# ## Initialize Natural Language Understanding API Service

# %%
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2017-02-27',
    username='10b31e8e-0f4d-44dc-b28e-5bed2d295fae',
    password='f1AE14yyUQtt')

# %% [markdown]
# ## Run the API Service on test sentence

# %%
response = natural_language_understanding.analyze(
    text=text_to_analyze,
    features=Features(emotion=EmotionOptions()))

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "joy": 0.857228,
#         "fear": 0.031575,
#         "anger": 0.018199,
#         "sadness": 0.023351,
#         "disgust": 0.003138
#       }
#     }
#   },
#   "usage": {
#     "text_units": 1,
#     "features": 1,
#     "text_characters": 84
#   }
# }

# %% [markdown]
# ## Run the API Service on test file 1

# %%
response = natural_language_understanding.analyze(
    text=file1.read(),
    features=Features(entities=EntitiesOptions(), keywords=KeywordsOptions()))

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "language": "en",
#   "keywords": [
#     {
#       "relevance": 0.923715,
#       "text": "kavik river camp"
#     },
#     {
#       "relevance": 0.790016,
#       "text": "North Slope"
#     },
#     {
#       "relevance": 0.78592,
#       "text": "seismologist Mike West"
#     },
#     {
#       "relevance": 0.706988,
#       "text": "U.S. Geological Survey"
#     },
#     {
#       "relevance": 0.678639,
#       "text": "powerful earthquake"
#     },
#     {
#       "relevance": 0.673932,
#       "text": "Anchorage Daily News"
#     },
#     {
#       "relevance": 0.571977,
#       "text": "second-biggest city"
#     },
#     {
#       "relevance": 0.523561,
#       "text": "kilometers"
#     },
#     {
#       "relevance": 0.519778,
#       "text": "significant event"
#     },
#     {
#       "relevance": 0.417814,
#       "text": "state"
#     },
#     {
#       "relevance": 0.402576,
#       "text": "miles"
#     },
#     {
#       "relevance": 0.381913,
#       "text": "Sunday"
#     },
#     {
#       "relevance": 0.376157,
#       "text": "Alaska"
#     },
#     {
#       "relevance": 0.365637,
#       "text": "magnitude"
#     },
#     {
#       "relevance": 0.363956,
#       "text": "AP"
#     },
#     {
#       "relevance": 0.352254,
#       "text": "Fairbanks"
#     },
#     {
#       "relevance": 0.344449,
#       "text": "depth"
#     },
#     {
#       "relevance": 0.343627,
#       "text": "region"
#     },
#     {
#       "relevance": 0.339351,
#       "text": "area"
#     }
#   ],
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 707
#   },
#   "entities": [
#     {
#       "relevance": 0.905875,
#       "type": "NaturalEvent",
#       "text": "earthquake",
#       "disambiguation": {
#         "name": "Earthquake",
#         "subtype": [
#           "CauseOfDeath",
#           "NaturalDisaster"
#         ],
#         "dbpedia_resource": "http://dbpedia.org/resource/Earthquake"
#       },
#       "count": 3
#     },
#     {
#       "relevance": 0.590528,
#       "type": "Facility",
#       "text": "KAVIK RIVER CAMP",
#       "count": 2
#     },
#     {
#       "relevance": 0.555367,
#       "type": "GeographicFeature",
#       "text": "North Slope",
#       "count": 2
#     },
#     {
#       "relevance": 0.417256,
#       "type": "PrintMedia",
#       "text": "Anchorage Daily News",
#       "disambiguation": {
#         "name": "Anchorage Daily News",
#         "subtype": [
#           "AwardWinner",
#           "Newspaper"
#         ],
#         "dbpedia_resource": "http://dbpedia.org/resource/Anchorage_Daily_News"
#       },
#       "count": 2
#     },
#     {
#       "relevance": 0.380364,
#       "type": "Location",
#       "text": "Alaska",
#       "disambiguation": {
#         "name": "Alaska",
#         "subtype": [
#           "PoliticalDistrict",
#           "AdministrativeDivision",
#           "GovernmentalJurisdiction",
#           "USState",
#           "StateOrCounty"
#         ],
#         "dbpedia_resource": "http://dbpedia.org/resource/Alaska"
#       },
#       "count": 2
#     },
#     {
#       "relevance": 0.309327,
#       "type": "Person",
#       "text": "Mike West",
#       "count": 2
#     },
#     {
#       "relevance": 0.260563,
#       "type": "Location",
#       "text": "Fairbanks",
#       "disambiguation": {
#         "name": "Fairbanks, Alaska",
#         "subtype": [
#           "City"
#         ],
#         "dbpedia_resource": "http://dbpedia.org/resource/Fairbanks,_Alaska"
#       },
#       "count": 1
#     },
#     {
#       "relevance": 0.202019,
#       "type": "Location",
#       "text": "U.S.",
#       "disambiguation": {
#         "name": "United States",
#         "subtype": [
#           "Region",
#           "AdministrativeDivision",
#           "GovernmentalJurisdiction",
#           "FilmEditor",
#           "Country"
#         ],
#         "dbpedia_resource": "http://dbpedia.org/resource/United_States"
#       },
#       "count": 1
#     },
#     {
#       "relevance": 0.202019,
#       "type": "Quantity",
#       "text": "551 kilometers",
#       "count": 1
#     },
#     {
#       "relevance": 0.202019,
#       "type": "Quantity",
#       "text": "9.9 kilometers",
#       "count": 1
#     },
#     {
#       "relevance": 0.202019,
#       "type": "Quantity",
#       "text": "67 kilometers",
#       "count": 1
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
    text=file2.read(),
    features=Features(entities=EntitiesOptions(), keywords=KeywordsOptions()))

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "language": "en",
#   "keywords": [
#     {
#       "relevance": 0.955782,
#       "text": "Secretary Jim Mattis"
#     },
#     {
#       "relevance": 0.793722,
#       "text": "separate military service"
#     },
#     {
#       "relevance": 0.757592,
#       "text": "defense secretary"
#     },
#     {
#       "relevance": 0.726375,
#       "text": "separate space service"
#     },
#     {
#       "relevance": 0.650953,
#       "text": "Space Force"
#     },
#     {
#       "relevance": 0.542299,
#       "text": "right way"
#     },
#     {
#       "relevance": 0.516053,
#       "text": "South America"
#     },
#     {
#       "relevance": 0.496761,
#       "text": "space problem"
#     },
#     {
#       "relevance": 0.459503,
#       "text": "Pentagon"
#     },
#     {
#       "relevance": 0.411776,
#       "text": "Brazil"
#     },
#     {
#       "relevance": 0.397424,
#       "text": "BRASILIA"
#     },
#     {
#       "relevance": 0.370206,
#       "text": "AP"
#     },
#     {
#       "relevance": 0.36014,
#       "text": "consensus"
#     },
#     {
#       "relevance": 0.356701,
#       "text": "moves"
#     },
#     {
#       "relevance": 0.349471,
#       "text": "reporters"
#     },
#     {
#       "relevance": 0.348829,
#       "text": "Congress"
#     },
#     {
#       "relevance": 0.345077,
#       "text": "U.S."
#     },
#     {
#       "relevance": 0.344856,
#       "text": "Sunday"
#     },
#     {
#       "relevance": 0.344008,
#       "text": "approach"
#     }
#   ],
#   "usage": {
#     "text_units": 1,
#     "features": 2,
#     "text_characters": 681
#   },
#   "entities": [
#     {
#       "relevance": 0.925543,
#       "type": "Person",
#       "text": "Jim Mattis",
#       "count": 5
#     },
#     {
#       "relevance": 0.508343,
#       "type": "Organization",
#       "text": "Pentagon",
#       "count": 2
#     },
#     {
#       "relevance": 0.446978,
#       "type": "Location",
#       "text": "Brazil",
#       "disambiguation": {
#         "name": "Brazil",
#         "subtype": [
#           "GovernmentalJurisdiction",
#           "CompanyShareholder",
#           "Country"
#         ],
#         "dbpedia_resource": "http://dbpedia.org/resource/Brazil"
#       },
#       "count": 2
#     },
#     {
#       "relevance": 0.421605,
#       "type": "Location",
#       "text": "BRASILIA",
#       "disambiguation": {
#         "name": "Bras\u00edlia",
#         "subtype": [
#           "City"
#         ],
#         "dbpedia_resource": "http://dbpedia.org/resource/Bras\u00edlia"
#       },
#       "count": 1
#     },
#     {
#       "relevance": 0.306384,
#       "type": "Organization",
#       "text": "Congress",
#       "disambiguation": {
#         "name": "United States Congress",
#         "subtype": [
#           "Dedicator",
#           "GovernmentalBody",
#           "Legislature",
#           "NaturalOrCulturalPreservationAgency"
#         ],
#         "dbpedia_resource": "http://dbpedia.org/resource/United_States_Congress"
#       },
#       "count": 1
#     },
#     {
#       "relevance": 0.300803,
#       "type": "Location",
#       "text": "South America",
#       "disambiguation": {
#         "name": "South America",
#         "subtype": [
#           "Continent"
#         ],
#         "dbpedia_resource": "http://dbpedia.org/resource/South_America"
#       },
#       "count": 1
#     },
#     {
#       "relevance": 0.234955,
#       "type": "Location",
#       "text": "U.S.",
#       "disambiguation": {
#         "name": "United States",
#         "subtype": [
#           "Region",
#           "AdministrativeDivision",
#           "GovernmentalJurisdiction",
#           "FilmEditor",
#           "Country"
#         ],
#         "dbpedia_resource": "http://dbpedia.org/resource/United_States"
#       },
#       "count": 1
#     }
#   ]
# }
